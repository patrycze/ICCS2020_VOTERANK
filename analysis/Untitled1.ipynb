# %%
import pandas as pd 
import matplotlib.pyplot as plt 

data_01 = pd.read_csv('../data/0.1_results_fix_interval_last.csv')
data_02 = pd.read_csv('../data/0.2_results_fix_interval_last.csv')
data_03 = pd.read_csv('../data/0.3_results_fix_interval_last.csv')
data_04 = pd.read_csv('../data/0.4_results_fix_interval_last.csv')
data_05 = pd.read_csv('../data/0.5_results_fix_interval_last.csv')
data_06 = pd.read_csv('../data/0.6_results_fix_interval_last.csv')
data_07 = pd.read_csv('../data/0.7_results_fix_interval_last.csv')
data_08 = pd.read_csv('../data/0.8_results_fix_interval_last.csv')
data_09 = pd.read_csv('../data/0.9_results_fix_interval_last.csv')

frames = [data_01, data_02, data_03, data_04, data_05, data_06, data_07, data_08, data_09]
data = pd.concat(frames)

# %%
data[data['limitPercentage'] == 1]
# Out:
#       nr  nazwa   pp  numberOfSeeds  seeds  totalNumberOfSeeds  numberOfNodes  \
# 0      6      8  0.1              1      1                 126          12591
# 1      6      8  0.1              2      2                 126          12591
# 2      6      8  0.1              4      4                 128          12591
# 3      6      8  0.1              8      8                 128          12591
# 4      6      8  0.1             16     16                 128          12591
# ...   ..    ...  ...            ...    ...                 ...            ...
# 4645   2      1  0.9              1      1                 163          16264
# 4646   2      1  0.9              2      2                 164          16264
# 4647   2      1  0.9              4      4                 164          16264
# 4648   2      1  0.9              8      8                 168          16264
# 4649   2      1  0.9             16     16                 176          16264
#
# ...

# %%
plt.figure();

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(30,20))


# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data[(data['interval'] == 8)]

subdata = subdata_1[subdata_1['numberOfSeeds'] == 2]
# ax.scatter(list(range(len(subdata.index))), subdata['seconds'], s=5, color='green')
ax.scatter(subdata['seconds'], subdata['infectedTotalPercentage'], s=15, color='green')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 4]
# ax.scatter(list(range(len(subdata.index))), subdata['infectedTotalPercentage'], s=1, color='red')
ax.scatter(subdata['seconds'], subdata['infectedTotalPercentage'], s=15, color='red')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 8]
# ax.scatter(list(range(len(subdata.index))), subdata['seconds'], s=5, color='blue')
ax.scatter(subdata['seconds'], subdata['infectedTotalPercentage'], s=15, color='blue')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 16]
# ax.scatter(list(range(len(subdata.index))), subdata['seconds'], s=15, color='pink')
ax.scatter(subdata['seconds'], subdata['infectedTotalPercentage'], s=15, color='pink')

plt.show()

subdata_1
# Out:
#       nr  nazwa   pp  numberOfSeeds  seeds  totalNumberOfSeeds  numberOfNodes  \
# 15     6      8  0.1              1      1                 126          12591
# 16     6      8  0.1              2      2                 126          12591
# 17     6      8  0.1              4      4                 128          12591
# 18     6      8  0.1              8      8                 128          12591
# 19     6      8  0.1             16     16                 128          12591
# ...   ..    ...  ...            ...    ...                 ...            ...
# 4665   2      1  0.9              1      1                 326          16264
# 4666   2      1  0.9              2      2                 326          16264
# 4667   2      1  0.9              4      4                 328          16264
# 4668   2      1  0.9              8      8                 328          16264
# 4669   2      1  0.9             16     16                 336          16264
#
# ...

# %%
# plt.figure();

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10,10))


# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data


subdata = subdata_1[subdata_1['numberOfSeeds'] == 1]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='black', label='1 seed')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 2]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='green', label='2 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 4]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='red', label='4 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 8]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='blue', label='8 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 16]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='pink', label='16 seeds')

ax.set_xlabel(r'Time (seconds)', fontsize=15)
ax.set_ylabel(r'Coverage (%)', fontsize=15)
ax.set_title('A. grouped by number of seeds', fontsize=20)

ax.grid(True)

ax.legend(loc='upper left')

plt.show()

# %%
# plt.figure();

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10,10))


# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data


subdata = subdata_1[subdata_1['limitPercentage'] == 1]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='black', label='1%')

subdata = subdata_1[subdata_1['limitPercentage'] == 2]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='green', label='2%')

subdata = subdata_1[subdata_1['limitPercentage'] == 3]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='red', label='3%')

subdata = subdata_1[subdata_1['limitPercentage'] == 4]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='blue', label='4%')

subdata = subdata_1[subdata_1['limitPercentage'] == 5]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='pink', label='5%')

ax.set_xlabel(r'Time (seconds)', fontsize=15)
ax.set_ylabel(r'Coverage (%)', fontsize=15)
ax.set_title('B. grouped by limit for seeds', fontsize=20)

ax.grid(True)

ax.legend(loc='upper left')

plt.show()

# %%
# plt.figure();

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10,10))


# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data


subdata = subdata_1[subdata_1['interval'] == 1]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='black', label='1 step')

subdata = subdata_1[subdata_1['interval'] == 2]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='green', label='2 step')

subdata = subdata_1[subdata_1['interval'] == 4]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='red', label='4 step')

subdata = subdata_1[subdata_1['interval'] == 8]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='blue', label='8 step')

subdata = subdata_1[subdata_1['interval'] == 16]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='pink', label='16 step')

ax.set_xlabel(r'Time (seconds)', fontsize=15)
ax.set_ylabel(r'Coverage (%)', fontsize=15)
ax.set_title('C. grouped by seeding inverval', fontsize=20)

ax.grid(True)

ax.legend(loc='upper right')

plt.show()

# %%
# plt.figure();

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10,10))


# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data[(data['interval'] == 16)]


subdata = subdata_1[subdata_1['numberOfSeeds'] == 1]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='black', label='1 seed')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 2]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='green', label='2 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 4]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='red', label='4 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 8]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='blue', label='8 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 16]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='pink', label='16 seeds')

ax.set_xlabel(r'Time (seconds)', fontsize=15)
ax.set_ylabel(r'Coverage (%)', fontsize=15)
ax.set_title('D. grouped by number of seeds for the best interval', fontsize=20)

ax.grid(True)

ax.legend(loc='upper left')

plt.show()

# %%
# plt.figure();

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10,10))


# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data[(data['interval'] == 1)]


subdata = subdata_1[subdata_1['numberOfSeeds'] == 1]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='black', label='1 seed')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 2]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='green', label='2 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 4]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='red', label='4 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 8]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='blue', label='8 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 16]
ax.scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='pink', label='16 seeds')

ax.set_xlabel(r'Time (seconds)', fontsize=15)
ax.set_ylabel(r'Coverage (%)', fontsize=15)
ax.set_title('E. grouped by number of seeds for the worst interval', fontsize=20)

ax.grid(True)

ax.legend(loc='upper left')

plt.show()

# %%
# plt.figure();

fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(20,10))


# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data[(data['interval'] == 1)]


subdata = subdata_1[subdata_1['numberOfSeeds'] == 1]
ax[0].scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='black', label='1 seed')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 2]
ax[0].scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='green', label='2 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 4]
ax[0].scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='red', label='4 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 8]
ax[0].scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='blue', label='8 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 16]
ax[0].scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='pink', label='16 seeds')

ax[0].set_xlabel(r'Time (seconds)', fontsize=15)
ax[0].set_ylabel(r'Coverage (%)', fontsize=15)
ax[0].set_title('E) grouped by number of seeds for the worst interval', fontsize=20)

ax[0].grid(True)

ax[0].legend(loc='upper left')



# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data[(data['interval'] == 16)]


subdata = subdata_1[subdata_1['numberOfSeeds'] == 1]
ax[1].scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='black', label='1 seed')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 2]
ax[1].scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='green', label='2 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 4]
ax[1].scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='red', label='4 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 8]
ax[1].scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='blue', label='8 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 16]
ax[1].scatter(subdata['seconds'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='pink', label='16 seeds')

ax[1].set_xlabel(r'Time (seconds)', fontsize=15)
ax[1].set_ylabel(r'Coverage (%)', fontsize=15)
ax[1].set_title('D) grouped by number of seeds for the best interval', fontsize=20)

ax[1].grid(True)

ax[1].legend(loc='upper left')





plt.show()

# %%
# plt.figure();

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10,10))


# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data


subdata = subdata_1[subdata_1['numberOfSeeds'] == 1]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='black', label='1 seed')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 2]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='green', label='2 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 4]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='red', label='4 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 8]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='blue', label='8 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 16]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='pink', label='16 seeds')

ax.set_xlabel(r'Steps', fontsize=15)
ax.set_ylabel(r'Coverage (%)', fontsize=15)
ax.set_title('2A grouped by number of seeds', fontsize=20)

ax.grid(True)

ax.legend(loc='upper left')

plt.show()

# %%
# plt.figure();

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10,10))


# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data


subdata = subdata_1[subdata_1['limitPercentage'] == 1]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='black', label='1%')

subdata = subdata_1[subdata_1['limitPercentage'] == 2]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='green', label='2%')

subdata = subdata_1[subdata_1['limitPercentage'] == 3]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='red', label='3%')

subdata = subdata_1[subdata_1['limitPercentage'] == 4]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='blue', label='4%')

subdata = subdata_1[subdata_1['limitPercentage'] == 5]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='pink', label='5%')

ax.set_xlabel(r'Steps', fontsize=15)
ax.set_ylabel(r'Coverage (%)', fontsize=15)
ax.set_title('2B) grouped by limit for seeds', fontsize=20)

ax.grid(True)

ax.legend(loc='upper left')

plt.show()

# %%
# plt.figure();

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10,10))


# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data


subdata = subdata_1[subdata_1['interval'] == 1]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='black', label='1 step')

subdata = subdata_1[subdata_1['interval'] == 2]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='green', label='2 step')

subdata = subdata_1[subdata_1['interval'] == 4]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='red', label='4 step')

subdata = subdata_1[subdata_1['interval'] == 8]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='blue', label='8 step')

subdata = subdata_1[subdata_1['interval'] == 16]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='pink', label='16 step')

ax.set_xlabel(r'Steps', fontsize=15)
ax.set_ylabel(r'Coverage (%)', fontsize=15)
ax.set_title('2C grouped by seeding inverval', fontsize=20)

ax.grid(True)

ax.legend(loc='upper left')

plt.show()

# %%
# plt.figure();

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10,10))


# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data[(data['interval'] == 16)]


subdata = subdata_1[subdata_1['numberOfSeeds'] == 1]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='black', label='1 seed')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 2]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='green', label='2 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 4]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='red', label='4 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 8]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='blue', label='8 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 16]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='pink', label='16 seeds')

ax.set_xlabel(r'Steps', fontsize=15)
ax.set_ylabel(r'Coverage (%)', fontsize=15)
ax.set_title('2D grouped by number of seeds for the best interval', fontsize=20)

ax.grid(True)

ax.legend(loc='upper left')

plt.show()

# %%
# plt.figure();

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10,10))


# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data[(data['interval'] == 1)]


subdata = subdata_1[subdata_1['numberOfSeeds'] == 1]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='black', label='1 seed')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 2]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='green', label='2 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 4]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='red', label='4 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 8]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='blue', label='8 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 16]
ax.scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='pink', label='16 seeds')

ax.set_xlabel(r'Steps', fontsize=15)
ax.set_ylabel(r'Coverage (%)', fontsize=15)
ax.set_title('2E grouped by number of seeds for the worst interval', fontsize=20)

ax.grid(True)

ax.legend(loc='upper left')

plt.show()

# %%
# plt.figure();

fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(20,10))


# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data[(data['interval'] == 1)]


subdata = subdata_1[subdata_1['numberOfSeeds'] == 1]
ax[0].scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='black', label='1 seed')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 2]
ax[0].scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='green', label='2 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 4]
ax[0].scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='red', label='4 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 8]
ax[0].scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='blue', label='8 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 16]
ax[0].scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='pink', label='16 seeds')

ax[0].set_xlabel(r'Step', fontsize=15)
ax[0].set_ylabel(r'Coverage (%)', fontsize=15)
ax[0].set_title('2E grouped by number of seeds for the worst interval', fontsize=20)

ax[0].grid(True)

ax[0].legend(loc='upper left')



# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data[(data['interval'] == 16)]


subdata = subdata_1[subdata_1['numberOfSeeds'] == 1]
ax[1].scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='black', label='1 seed')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 2]
ax[1].scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='green', label='2 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 4]
ax[1].scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='red', label='4 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 8]
ax[1].scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='blue', label='8 seeds')

subdata = subdata_1[subdata_1['numberOfSeeds'] == 16]
ax[1].scatter(subdata['steps'].mean(), subdata['infectedTotalPercentage'].mean(), s=125, color='pink', label='16 seeds')

ax[1].set_xlabel(r'Step', fontsize=15)
ax[1].set_ylabel(r'Coverage (%)', fontsize=15)
ax[1].set_title('2D grouped by number of seeds for the best interval', fontsize=20)

ax[1].grid(True)

ax[1].legend(loc='upper left')





plt.show()

# %%
plt.figure();

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(30,20))


# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data


subdata = subdata_1[subdata_1['numberOfSeeds'] == 1]
ax.bar(['1'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['numberOfSeeds'] == 2]
ax.bar(['2'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['numberOfSeeds'] == 4]
ax.bar(['4'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['numberOfSeeds'] == 8]
ax.bar(['8'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['numberOfSeeds'] == 16]
ax.bar(['16'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
plt.show()
# Out:
# 80.23437738366837
# 80.13494553826295
# 79.98139409129942
# 79.72662196850898
# 79.3626581349347

# %%
plt.figure();

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(30,20))


# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data


subdata = subdata_1[subdata_1['limitPercentage'] == 1]
ax.bar(['1'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['limitPercentage'] == 2]
ax.bar(['2'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['limitPercentage'] == 3]
ax.bar(['4'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['limitPercentage'] == 4]
ax.bar(['8'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['limitPercentage'] == 5]
ax.bar(['16'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
plt.show()
# Out:
# 75.90368719563016
# 78.54897918314575
# 80.42938051314914
# 81.81746410188528
# 82.91641816550218

# %%
plt.figure();

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(30,20))


# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data


subdata = subdata_1[subdata_1['pp'] == 0.1]
ax.bar(['1'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['pp'] == 0.2]
ax.bar(['2'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['pp'] == 0.3]
ax.bar(['3'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['pp'] == 0.4]
ax.bar(['4'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['pp'] == 0.5]
ax.bar(['5'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['pp'] == 0.6]
ax.bar(['6'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['pp'] == 0.7]
ax.bar(['7'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['pp'] == 0.8]
ax.bar(['8'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['pp'] == 0.9]
ax.bar(['9'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())

plt.show()
# Out:
# 33.01040918723189
# 50.323621804656455
# 68.7329508254072
# 72.48643906861322
# 73.81334634613677
# 82.2085529063069
# 88.966975865496
# 94.08923976304325
# 97.79346690056383

# %%
plt.figure();

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(30,20))


# subdata_1 = data[(data['interval'] == 1) & (data['limitPercentage'] == 3) & (data['pp'] == 0.2)]
subdata_1 = data


subdata = subdata_1[subdata_1['interval'] == 1]
ax.bar(['1'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['interval'] == 2]
ax.bar(['2'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['interval'] == 4]
ax.bar(['4'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['interval'] == 8]
ax.bar(['8'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
subdata = subdata_1[subdata_1['interval'] == 16]
ax.bar(['16'], subdata['infectedTotalPercentage'].mean(), color='black')
print(subdata['infectedTotalPercentage'].mean())
plt.show()

subdata
# Out:
# 79.31971331142154
# 79.73732343214412
# 79.99721705244491
# 80.17678303840871
# 80.21374700750962
#       nr  nazwa   pp  numberOfSeeds  seeds  totalNumberOfSeeds  numberOfNodes  \
# 20     6      8  0.1              1      1                 126          12591
# 21     6      8  0.1              2      2                 126          12591
# 22     6      8  0.1              4      4                 128          12591
# 23     6      8  0.1              8      8                 128          12591
# 24     6      8  0.1             16     16                 128          12591
# ...   ..    ...  ...            ...    ...                 ...            ...
# 3670   8      4  0.9              1      1                  99           4941
# 3671   8      4  0.9              2      2                 100           4941
# 3672   8      4  0.9              4      4                 102           4941
# 3673   8      4  0.9              8      8                 104           4941
# ...

# %%
from datetime import timedelta

def changeToDate(x, mapa, unique):
    replaced = x.replace('(', '').replace('[', '').replace(' ', '').replace(')]', '')
    
    if(replaced not in unique):
        unique.append(replaced)

        splited = replaced.split(',')
#         print(splited, 'm', splited[0], 's', splited[1], 'msec', splited[2])

        mapa['m'] += int(splited[0])
        mapa['s'] += int(splited[1])
        mapa['msec'] += int(splited[2])
#         print(mapa)

def convert(x):
    temp = x.replace('datetime.timedelta', '').split('),')
#     print('nowy')
    mapa = {'m': 0, 's': 0, 'msec': 0}
    unique = []

    for tmp in temp:        
        changeToDate(tmp, mapa, unique)
        
#     print('koniec z czasem', timedelta(mapa['m'], mapa['s'], mapa['msec']).total_seconds())
    return timedelta(mapa['m'], mapa['s'], mapa['msec']).total_seconds()

#     print([tmp for tmp in temp])
#     print([tmp.apply(lambda x: x.replace('(', '')) for tmp in temp])


# data_with[71:72].apply(lambda x: convert(x['computionalTime']), axis=1)
# data_without[71:72].apply(lambda x: convert(x['computionalTime']), axis=1)

data['seconds'] = data.apply(lambda x: convert(x['computionalTime']), axis=1)

# data_with[np.isclose(data_with['infectedTotalPercentage'],95.525154, 0.0001)].apply(lambda x: convert(x['computionalTime']), axis=1)
