# %%
import pandas as pd

data_01 = pd.read_csv('../data/0.1_results_fix_interval.csv')
data_02 = pd.read_csv('../data/0.2_results_fix_interval.csv')
data_03 = pd.read_csv('../data/0.3_results_fix_interval.csv')
data_04 = pd.read_csv('../data/0.4_results_fix_interval.csv')
data_05 = pd.read_csv('../data/0.5_results_fix_interval.csv')
data_06 = pd.read_csv('../data/0.6_results_fix_interval.csv')
data_07 = pd.read_csv('../data/0.7_results_fix_interval.csv')
data_08 = pd.read_csv('../data/0.8_results_fix_interval.csv')
data_09 = pd.read_csv('../data/0.9_results_fix_interval.csv')

# %%
frames = [data_02, data_03, data_04, data_05, data_06, data_07, data_08, data_09]
data = pd.concat(frames)

# %%
subdata = data[(data['nr'] == 1) & (data['nazwa'] == 2) & (data['pp'] == 0.3) & (data['numberOfSeeds'] == 8) & (data['interval'] == 2)]

# %%
# subdata.apply(lambda x: print(x), axis=1)
subdata
# Out:
#         nr  nazwa   pp  numberOfSeeds  \
# 742      1      2  0.3              8
# 743      1      2  0.3              8
# 744      1      2  0.3              8
# 745      1      2  0.3              8
# 746      1      2  0.3              8
# ...     ..    ...  ...            ...
# 130228   1      2  0.3              8
# 130229   1      2  0.3              8
# 130230   1      2  0.3              8
# 130299   1      2  0.3              8
# 130300   1      2  0.3              8
#
#                                                 seeds  totalNumberOfSeeds  \
# 742                 [103, 9, 105, 400, 32, 3, 41, 42]                   8
# 743          [249, 1283, 357, 840, 19, 704, 204, 176]                  16
# 744          [249, 1283, 357, 840, 19, 704, 204, 176]                  16
# 745        [1712, 1862, 1801, 1876, 10, 22, 137, 160]                  24
# 746        [1712, 1862, 1801, 1876, 10, 22, 137, 160]                  24
# ...
