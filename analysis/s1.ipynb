# %%
import pandas as pd 
import matplotlib.pyplot as plt 

data_01 = pd.read_csv('../data/0.1_results_fix_interval.csv')
data_02 = pd.read_csv('../data/0.2_results_fix_interval.csv')
data_03 = pd.read_csv('../data/0.3_results_fix_interval.csv')
data_04 = pd.read_csv('../data/0.4_results_fix_interval.csv')
data_05 = pd.read_csv('../data/0.5_results_fix_interval.csv')
data_06 = pd.read_csv('../data/0.6_results_fix_interval.csv')
data_07 = pd.read_csv('../data/0.7_results_fix_interval.csv')
data_08 = pd.read_csv('../data/0.8_results_fix_interval.csv')
data_09 = pd.read_csv('../data/0.9_results_fix_interval.csv')

frames = [data_01, data_02, data_03, data_04, data_05, data_06, data_07, data_08, data_09]
data = pd.concat(frames)

# %%
interval = 2
numberOfSeeds = 2

subdata = data[(data['nr'] == 1) & (data['nazwa'] == 2) & (data['pp'] == 0.3) & (data['numberOfSeeds'] == numberOfSeeds) & (data['interval'] == interval)]

subdata
# Out:
#         nr  nazwa   pp  numberOfSeeds         seeds  totalNumberOfSeeds  \
# 0        1      2  0.3              2      [103, 9]                   2
# 1        1      2  0.3              2    [105, 400]                   4
# 2        1      2  0.3              2    [105, 400]                   4
# 3        1      2  0.3              2   [699, 1712]                   6
# 4        1      2  0.3              2   [699, 1712]                   6
# ...     ..    ...  ...            ...           ...                 ...
# 129848   1      2  0.3              2   [1614, 718]                 484
# 129849   1      2  0.3              2  [1569, 1569]                 485
# 129850   1      2  0.3              2  [1569, 1569]                 485
# 129851   1      2  0.3              2  [1804, 1804]                 486
# 129852   1      2  0.3              2  [1804, 1804]                 486
#
#         numberOfNodes  step  infectedPerStep  infectedTotal  \
# ...

# %%
# wyliczam średnią dla przebiegów 


interval = 2
numberOfSeeds = 2
pp = 0.2
nr = 4
# okreslenie ktora czesc datasetu nas interesuje
data.loc[(data['numberOfSeeds'] == numberOfSeeds) & (data['interval'] == interval) & (data['pp'] == pp)  & (data['nr'] == nr)]
# Out:
#        nr  nazwa   pp  numberOfSeeds         seeds  totalNumberOfSeeds  \
# 57016   4      2  0.2              2      [103, 9]                   2
# 57017   4      2  0.2              2    [105, 400]                   4
# 57018   4      2  0.2              2    [105, 400]                   4
# 57019   4      2  0.2              2   [1393, 735]                   6
# 57020   4      2  0.2              2   [1393, 735]                   6
# ...    ..    ...  ...            ...           ...                 ...
# 57698   4      2  0.2              2    [591, 591]                 681
# 57699   4      2  0.2              2   [1810, 957]                 683
# 57700   4      2  0.2              2   [1810, 957]                 683
# 58047   4      2  0.2              2  [1690, 1152]                 687
# 58048   4      2  0.2              2  [1690, 1152]                 687
#
#        numberOfNodes  step  infectedPerStep  infectedTotal  \
# ...

# %%
# data.groupby(['nr']).mean()

interval = 2
numberOfSeeds = 2
pp = 0.4
nr = 3

# okreslenie ktora czesc datasetu nas interesuje
subdata_1 = data.loc[(data['numberOfSeeds'] == numberOfSeeds) & (data['interval'] == interval) & (data['pp'] == pp)  & (data['nr'] == nr)]


interval = 2
numberOfSeeds = 4


# okreslenie ktora czesc datasetu nas interesuje
subdata_2 = data.loc[(data['numberOfSeeds'] == numberOfSeeds) & (data['interval'] == interval) & (data['pp'] == pp)  & (data['nr'] == nr)]


interval = 2
numberOfSeeds = 8


# okreslenie ktora czesc datasetu nas interesuje
subdata_3 = data.loc[(data['numberOfSeeds'] == numberOfSeeds) & (data['interval'] == interval) & (data['pp'] == pp)  & (data['nr'] == nr)]



aggregatedTime = 0 

def aggregatedComputionalTime(time):
    global aggregatedTime
    
#     print(aggregatedTime)
    
    aggregatedTime = float(time[5:]) + float(aggregatedTime)
    
    return aggregatedTime

subdata_1['aggregatedComputionalTime'] = subdata_1.apply(lambda x: aggregatedComputionalTime(x['computionalTime']), axis=1)

aggregatedTime = 0 

subdata_2['aggregatedComputionalTime'] = subdata_2.apply(lambda x: aggregatedComputionalTime(x['computionalTime']), axis=1)

aggregatedTime = 0 

subdata_3['aggregatedComputionalTime'] = subdata_3.apply(lambda x: aggregatedComputionalTime(x['computionalTime']), axis=1)


plt.figure();

fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(30,10))

ax[0].scatter(list(range(len(subdata_1.index))), subdata_1['infectedTotalPercentage'], s=5)
# ax[0].scatter(list(range(len(subdata_2.index))), subdata_2['infectedTotalPercentage'], s=2)
# ax[0].scatter(list(range(len(subdata_3.index))), subdata_3['infectedTotalPercentage'], s=2)



ax[1].scatter(list(range(len(subdata_1.index))), subdata_1['totalNumberOfSeeds'], s=5)
# ax[1].scatter(list(range(len(subdata_2.index))), subdata_2['aggregatedComputionalTime'], s=2)
# ax[1].scatter(list(range(len(subdata_3.index))), subdata_3['aggregatedComputionalTime'], s=2)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
aggregatedTime = 0 

def aggregatedComputionalTime(time):
    global aggregatedTime
    
    print(aggregatedTime)
    
    aggregatedTime = float(time[5:]) + float(aggregatedTime)
    
    return aggregatedTime

# data['aggregatedComputionalTime'] = data.apply(lambda x: aggregatedComputionalTime(x['computionalTime']), axis=1)

# %%
from timeit import default_timer as timer
from datetime import timedelta

start = timer()
end = timer()

timedelta(seconds=end-start)
# Out:
# datetime.timedelta(0, 0, 15)

# %%
subdata_2
# Out:
#       nr  nazwa   pp  numberOfSeeds  \
# 993    1      2  0.1              8
# 994    1      2  0.1              8
# 995    1      2  0.1              8
# 996    1      2  0.1              8
# 997    1      2  0.1              8
# ...   ..    ...  ...            ...
# 1239   1      2  0.1              8
# 1240   1      2  0.1              8
# 1241   1      2  0.1              8
# 1242   1      2  0.1              8
# 1243   1      2  0.1              8
#
#                                                seeds  totalNumberOfSeeds  \
# 993                [103, 9, 105, 400, 32, 3, 41, 42]                   8
# 994         [713, 249, 194, 1283, 67, 357, 372, 598]                  16
# 995         [713, 249, 194, 1283, 67, 357, 372, 598]                  16
# 996        [128, 44, 687, 655, 1488, 609, 852, 1000]                  24
# 997        [128, 44, 687, 655, 1488, 609, 852, 1000]                  24
# ...                                              ...                 ...
# ...
